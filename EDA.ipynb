# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("/Users/ks/Downloads/imports-85.data",header=None,na_values='?')
data.head()
data.columns=["symboling","normalized-losses","make","fuel_type","aspiration","num-of_doors","body_style","drive_wheels","engine_location","wheel_base","length","width","height","curb_weight","engine_type","num-of-cylinders","engine-size","fuel_system","bore","stroke","compression_ratio","horsepower","peak_rpm","city_mpg","highway_mpg","price"]
data.head()
# Out:
#    symboling  normalized-losses         make fuel_type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="highway_mpg",y="horsepower",data=data)

# %%
plt.subplot(1,2,1)
plt.boxplot(data.highway_mpg)
plt.subplot(1,2,2)
plt.boxplot(data.horsepower)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe5520c8310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe5520c8a30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe5520b7f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe5520d5190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe5520d5520>],
#  'means': []}

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'symboling'}>,
#         <AxesSubplot:title={'center':'normalized-losses'}>,
#         <AxesSubplot:title={'center':'wheel_base'}>,
#         <AxesSubplot:title={'center':'length'}>],
#        [<AxesSubplot:title={'center':'width'}>,
#         <AxesSubplot:title={'center':'height'}>,
#         <AxesSubplot:title={'center':'curb_weight'}>,
#         <AxesSubplot:title={'center':'engine-size'}>],
#        [<AxesSubplot:title={'center':'bore'}>,
#         <AxesSubplot:title={'center':'stroke'}>,
#         <AxesSubplot:title={'center':'compression_ratio'}>,
#         <AxesSubplot:title={'center':'horsepower'}>],
#        [<AxesSubplot:title={'center':'peak_rpm'}>,
#         <AxesSubplot:title={'center':'city_mpg'}>,
#         <AxesSubplot:title={'center':'highway_mpg'}>,
#         <AxesSubplot:title={'center':'price'}>]], dtype=object)

# %%
sns.countplot(y="highway_mpg",data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='highway_mpg'>

# %%
from scipy import stats
stats.shapiro(data.highway_mpg)
# Out:
# ShapiroResult(statistic=0.9735103845596313, pvalue=0.0006515368004329503)

# %%
sns.countplot(x="fuel_system",data=data)
# Out:
# <AxesSubplot:xlabel='fuel_system', ylabel='count'>

# %%
data.fuel_system=data.fuel_system.replace("mfi","4bbl")
data.fuel_system=data.fuel_system.replace("spfi","4bbl")

# %%
data.fuel_system=data.fuel_system.replace("4bbl","1bbl")

# %%
data.fuel_system=data.fuel_system.replace("1bbl","spdi")

# %%
data.fuel_system=data.fuel_system.replace("spdi","others")

# %%
data.horsepower.unique()
# Out:
# array([111., 154., 102., 115., 110., 140., 160., 101., 121., 182.,  48.,
#         70.,  68.,  88., 145.,  58.,  76.,  60.,  86., 100.,  78.,  90.,
#        176., 262., 135.,  84.,  64., 120.,  72., 123., 155., 184., 175.,
#        116.,  69.,  55.,  97., 152., 200.,  95., 142., 143., 207., 288.,
#         nan,  73.,  82.,  94.,  62.,  56., 112.,  92., 161., 156.,  52.,
#         85., 114., 162., 134., 106.])

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="highway_mpg",y="fuel_system",data=data)

# %%
sns.countplot(x="engine_type",data=data)
# Out:
# <AxesSubplot:xlabel='engine_type', ylabel='count'>

# %%
data.engine_type=data.engine_type.replace("ohcv","dohc")
data.engine_type=data.engine_type.replace("l","dohc")
data.engine_type=data.engine_type.replace("dohcv","dohc")
data.engine_type=data.engine_type.replace("rotor","dohc")
data.engine_type=data.engine_type.replace("ohcf","dohc")
data.engine_type=data.engine_type.replace("dohc","others")

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="highway_mpg",y="engine_type",data=data)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="highway_mpg",y="stroke",data=data)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="highway_mpg",y="peak_rpm",data=data)

# %%
sns.countplot(x="peak_rpm",data=data)
# Out:
# <AxesSubplot:xlabel='peak_rpm', ylabel='count'>

# %%
stats.shapiro(data.peak_rpm)
# Out:
# ShapiroResult(statistic=nan, pvalue=1.0)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="highway_mpg",y="compression_ratio",data=data)

# %%
plt.boxplot(data.compression_ratio)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fca72992790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fca72a93220>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fca729922b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca72a93d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca72a93f10>],
#  'means': []}

# %%
plt.subplot(1,2,1)
plt.boxplot(data.highway_mpg)
plt.subplot(1,2,2)
plt.boxplot(data.compression_ratio)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fca4017a8b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fca4017afd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fca4017a520>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca40172940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca40172ee0>],
#  'means': []}

# %%
stats.ttest_rel(data.highway_mpg, data.compression_ratio)
# Out:
# Ttest_relResult(statistic=42.28618215294645, pvalue=6.63562422800714e-103)

# %%
data.compression_ratio.unique()
# Out:
# array([ 9.  , 10.  ,  8.  ,  8.5 ,  8.3 ,  7.  ,  8.8 ,  9.5 ,  9.6 ,
#         9.41,  9.4 ,  7.6 ,  9.2 , 10.1 ,  9.1 ,  8.1 , 11.5 ,  8.6 ,
#        22.7 , 22.  , 21.5 ,  7.5 , 21.9 ,  7.8 ,  8.4 , 21.  ,  8.7 ,
#         9.31,  9.3 ,  7.7 , 22.5 , 23.  ])

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="city_mpg",y="horsepower",data=data)

# %%
sns.countplot(x="city_mpg",data=data)
# Out:
# <AxesSubplot:xlabel='city_mpg', ylabel='count'>

# %%
stats.shapiro(data.city_mpg)
# Out:
# ShapiroResult(statistic=0.9572238922119141, pvalue=7.825866305211093e-06)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="city_mpg",y="fuel_system",data=data)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="city_mpg",y="engine_type",data=data)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="city_mpg",y="stroke",data=data)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="city_mpg",y="peak_rpm",data=data)

# %%
plt.figure(figsize=(8,6))
sns.catplot(x="city_mpg",y="compression_ratio",data=data)

# %%
plt.subplot(1,2,1)
plt.boxplot(data.city_mpg)
plt.subplot(1,2,2)
plt.boxplot(data.compression_ratio)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fca8422a310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fca8422aa60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fca8422a0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca842381c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca84238550>],
#  'means': []}

# %%
stats.ttest_ind(data.city_mpg, data.compression_ratio)
# Out:
# Ttest_indResult(statistic=28.205164145430597, pvalue=7.031845746684078e-98)

# %%
Q3=data.compression_ratio.quantile(0.75)

# %%
Q1=data.compression_ratio.quantile(0.25)

# %%
Q2=data.compression_ratio.quantile(0.50)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 0.8000000000000007

# %%
UE=Q3+1.5*IQR
UE
# Out:
# 10.600000000000001

# %%
LE=Q3-1.5*IQR
LE
# Out:
# 8.2

# %%
data[(data.compression_ratio<UE)&
    (data.compression_ratio>LE)]
# Out:
#      symboling  normalized-losses         make fuel_type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 197         -1               74.0        volvo       gas        std
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %%
data.compression_ratio[data.compression_ratio>UE]
# Out:
# 49     11.5
# 63     22.7
# 66     22.0
# 67     21.5
# 68     21.5
# 69     21.5
# 70     21.5
# 90     21.9
# 108    21.0
# 110    21.0
# 112    21.0
# 114    21.0
# 116    21.0
# 158    22.5
# 159    22.5
# 174    22.5
# 182    23.0
# 184    23.0
# 187    23.0
# 192    23.0
# 203    23.0
# Name: compression_ratio, dtype: float64

# %%
data.compression_ratio[data.compression_ratio<LE]
# Out:
# 4      8.0
# 9      7.0
# 15     8.0
# 16     8.0
# 17     8.0
# 23     7.6
# 27     7.6
# 29     7.0
# 47     8.1
# 48     8.1
# 65     8.0
# 73     8.0
# 74     8.0
# 75     8.0
# 79     7.6
# 80     7.5
# 82     7.0
# 83     7.0
# 84     7.0
# 87     7.5
# 88     7.5
# 105    7.8
# 117    7.0
# 119    7.6
# 124    7.0
# 145    7.7
# 149    7.7
# 198    7.5
# 199    7.5
# Name: compression_ratio, dtype: float64
