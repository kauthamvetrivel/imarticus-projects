# %%
import pandas as pd

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test (1).csv")
sample = pd.read_csv("sample.csv")

# %%
train
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 14571  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 14572               LMA Manager 2007     X360           2006.0        Sports
# 14573        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 14574               Spirits & Spells      GBA           2003.0      Platform
# 14575            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Critic_Score  Critic_Count  \
# 0          Nintendo     41.36     28.96      3.77          76.0          51.0
# 1          Nintendo     29.08      3.58      6.81           NaN           NaN
# 2          Nintendo     15.68     12.76      3.79          82.0          73.0
# 3          Nintendo     15.61     10.93      3.28          80.0          73.0
# 4          Nintendo     11.27      8.89     10.22           NaN           NaN
# ...             ...       ...       ...       ...           ...           ...
# 14571    Tecmo Koei      0.00      0.00      0.01           NaN           NaN
# 14572   Codemasters      0.00      0.01      0.00           NaN           NaN
# 14573  Idea Factory      0.00      0.00      0.01           NaN           NaN
# 14574       Wanadoo      0.01      0.00      0.00           NaN           NaN
# 14575    Tecmo Koei      0.00      0.00      0.01           NaN           NaN
#
#       User_Score  User_Count Developer Rating  Global_Sales
# 0              8       322.0  Nintendo      E         82.53
# 1            NaN         NaN       NaN    NaN         40.24
# 2            8.3       709.0  Nintendo      E         35.52
# 3              8       192.0  Nintendo      E         32.77
# 4            NaN         NaN       NaN    NaN         31.37
# ...          ...         ...       ...    ...           ...
# 14571        NaN         NaN       NaN    NaN          0.01
# 14572        NaN         NaN       NaN    NaN          0.01
# 14573        NaN         NaN       NaN    NaN          0.01
# 14574        NaN         NaN       NaN    NaN          0.01
# 14575        NaN         NaN       NaN    NaN          0.01
#
# [14576 rows x 15 columns]

# %%
trainy = train.iloc[0:,14]
trainx = train.iloc[0:,0:14]

# %%
trainx.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Critic_Score  Critic_Count User_Score  \
# 0     41.36     28.96      3.77          76.0          51.0          8
# 1     29.08      3.58      6.81           NaN           NaN        NaN
# 2     15.68     12.76      3.79          82.0          73.0        8.3
# 3     15.61     10.93      3.28          80.0          73.0          8
# 4     11.27      8.89     10.22           NaN           NaN        NaN
#
#    User_Count Developer Rating
# 0       322.0  Nintendo      E
# 1         NaN       NaN    NaN
# 2       709.0  Nintendo      E
# 3       192.0  Nintendo      E
# 4         NaN       NaN    NaN

# %%
data = trainx.append(test,sort=False,ignore_index=True)

# %%
data.drop(index=[659,12103],inplace = True)

# %%
cc =data[data.Critic_Count.isnull()]
cc.Publisher.unique()
# Out:
# array(['Nintendo', 'Activision', 'Microsoft Game Studios', 'Sega',
#        'Electronic Arts', 'Atari', 'Sony Computer Entertainment',
#        '505 Games', 'Capcom', 'Eidos Interactive', 'Vivendi Games',
#        'Enix Corporation', 'Sony Computer Entertainment Europe', 'Palcom',
#        'Hasbro Interactive', 'Konami Digital Entertainment',
#        'Virgin Interactive', 'Ubisoft', 'THQ', 'Fox Interactive',
#        'SquareSoft', 'Acclaim Entertainment',
#        'Disney Interactive Studios', 'Namco Bandai Games', 'Codemasters',
#        'Majesco Entertainment', 'Red Orb', 'GT Interactive', 'Level 5',
#        'Arena Entertainment', 'Take-Two Interactive', 'Square Enix',
#        'JVC', '989 Studios', 'UEP Systems', 'Parker Bros.', 'Maxis',
#        'Imagic', 'ASCII Entertainment', 'Mindscape', 'LucasArts',
#        'Unknown', 'Square', 'Bethesda Softworks', 'Banpresto',
#        'D3Publisher', 'Activision Value', 'Oxygen Interactive',
#        'Red Storm Entertainment', 'Video System', 'Westwood Studios',
#        'GungHo', 'Midway Games', 'Hudson Soft', 'Coleco',
#        'Rising Star Games', 'Warner Bros. Interactive Entertainment',
#        'ASC Games', 'Accolade', '3DO', 'Natsume', 'Alchemist',
#        'Focus Home Interactive', 'Ocean', 'Psygnosis', 'Success',
#        'Compile', 'Taito', 'Agetec', 'Microprose', 'GSP', 'Tecmo Koei',
#        'Sammy Corporation', 'Koch Media', 'Empire Interactive', 'Mojang',
#        'CTO SpA', 'Crystal Dynamics', 'Infogrames', 'mixi, Inc',
#        'Pinnacle', 'Quelle', 'Interplay', 'Mystique', 'ChunSoft',
#        '20th Century Fox Video Games', 'Hudson Entertainment',
#        'Men-A-Vision', 'SCi', 'Nobilis', 'Avanquest Software',
#        'Gotham Games', 'Big Ben Interactive', 'Nordic Games',
#        'LEGO Media', 'Quest', 'Tigervision', 'Rocket Company',
#        'Mattel Interactive', 'IE Institute', 'Funbox Media',
#        'Deep Silver', 'Universal Gamex', 'Wizard Video Games',
#        'MTV Games', 'BMG Interactive Entertainment',
#        'Universal Interactive', 'Zoo Digital Publishing', 'Laguna',
#        'Takara', 'Enterbrain', 'Imagineer', 'CPG Products',
#        'System 3 Arcade Software', 'Aruze Corp', 'Destineer', 'Jaleco',
#        'Answer Software', 'Rondomedia', 'Scholastic Inc.', 'Pack In Soft',
#        'Nippon Ichi Software', 'XS Games', 'Ultravision', 'Titus',
#        'Telltale Games', 'Epoch', 'GameMill Entertainment', 'Atlus',
#        'Tomy Corporation', 'Knowledge Adventure', 'BAM! Entertainment',
#        'Mastiff', 'ESP', 'TYO', 'Telegames', 'Mud Duck Productions',
#        'Pioneer LDC', 'Magical Company', 'Kemco', 'Mentor Interactive',
#        'Zoo Games', 'RTL', 'Human Entertainment', 'Data Age',
#        'Electronic Arts Victor', 'Jack of All Games', 'Avanquest',
#        '989 Sports', 'Media Rings', 'Elf', 'Game Factory', 'Starfish',
#        'Zushi Games', 'Jorudan', 'Destination Software, Inc', 'New',
#        'Brash Entertainment', 'ITT Family Games', 'Ackkstudios',
#        'Starpath Corp.', 'Play It', 'City Interactive', 'SouthPeak Games',
#        'BPS', 'NewKidCo', 'Storm City Games', 'CokeM Interactive',
#        'P2 Games', 'CBS Electronics', 'Magix',
#        'Midas Interactive Entertainment', 'Spike',
#        'Marvelous Entertainment', 'Angel Studios', 'Playmates',
#        'Marvelous Interactive', 'SNK Playmore', 'Hamster Corporation',
#        'TDK Mediactive', 'From Software', 'Nippon Columbia', 'Nichibutsu',
#        'Conspiracy Entertainment', 'Hect', 'Crave Entertainment',
#        'DTP Entertainment', 'NEC', 'Axela', 'ArtDink', 'Sunsoft',
#        'Little Orbit', 'Gust', 'SNK', 'NEC Interchannel', 'Global Star',
#        'Xing Entertainment', 'ValuSoft', 'PopCap Games',
#        'Victor Interactive', 'Kadokawa Shoten', 'American Softworks',
#        'Detn8 Games', 'Bomb', 'Nordcurrent', 'Ghostlight', 'Sears',
#        'Seta Corporation', 'On Demand', 'NCS', 'Falcom Corporation',
#        'Gremlin Interactive Ltd', 'Culture Brain', 'Shogakukan',
#        'Merscom LLC', 'JoWood Productions', 'Nippon Telenet',
#        'Kadokawa Games', 'SSI', 'Foreign Media Games', 'Core Design Ltd.',
#        'Arc System Works', 'Astragon', 'TDK Core', 'Black Bean Games',
#        'Asylum Entertainment', 'UFO Interactive', 'Essential Games',
#        'Adeline Software', 'PlayV', 'Genki', 'Mumbo Jumbo',
#        'Panther Software', 'Blast! Entertainment Ltd',
#        'Performance Designed Products', 'DSI Games', 'Avalon Interactive',
#        'Popcorn Arcade', 'Aques', 'Aspyr', 'Syscom', 'Vir2L Studios',
#        'Neko Entertainment', 'Nihon Falcom Corporation',
#        'Ignition Entertainment', 'Vic Tokai', 'Media Factory', 'Xplosiv',
#        'Game Arts', 'Broccoli', 'General Entertainment', 'Acquire',
#        'Imadio', 'Sony Music Entertainment', 'Aqua Plus',
#        'Excalibur Publishing', 'Data East', 'Time Warner Interactive',
#        'Gainax Network Systems', 'Daito', 'Milestone S.r.l.',
#        'O3 Entertainment', 'O-Games', 'Takara Tomy', 'Xicat Interactive',
#        'Simon & Schuster Interactive', 'PopTop Software', 'TOHO', '5pb',
#        'Ubisoft Annecy', 'PQube', 'DreamCatcher Interactive',
#        'Mastertronic', 'Paon', 'Idea Factory', 'U.S. Gold',
#        'AQ Interactive', 'CDV Software Entertainment', 'Micro Cabin',
#        'Compile Heart', 'GameTek', 'Benesse', 'Type-Moon',
#        'Enjoy Gaming ltd.', 'MTO', 'Asmik Corp', 'Interplay Productions',
#        'Asmik Ace Entertainment', 'Image Epoch',
#        'Idea Factory International', 'responDESIGN',
#        'Data Design Interactive', 'Griffin International',
#        'Culture Publishers', 'FuRyu', 'Bigben Interactive',
#        'Habro Interactive', 'Hackberry', 'HAL Laboratory', 'Phenomedia',
#        'Grand Prix Games', 'Mercury Games', 'DigiCube', 'Creative Core',
#        'Kaga Create', 'WayForward Technologies', 'Pack-In-Video',
#        'LSP Games', 'ASCII Media Works', 'Coconuts Japan', 'Arika',
#        'Tivola', 'Marvel Entertainment', 'Swing! Entertainment', 'Asgard',
#        'Prototype', 'The Learning Company', 'TechnoSoft', 'Aksys Games',
#        'MLB.com', 'Valcon Games', 'Irem Software Engineering', 'Vap',
#        'Misawa', 'Yeti', 'Pow', 'MediaQuest', 'Metro 3D', 'Tradewest',
#        'Happinet', 'Comfort', 'Home Entertainment Suppliers',
#        'Pony Canyon', 'Riverhillsoft', 'Media Works', 'Summitsoft',
#        'Playmore', 'TopWare Interactive', 'Tommo', 'NCSoft',
#        'Slitherine Software', 'Hudson soft', 'CyberFront',
#        'Alawar Entertainment', 'Graffiti', 'Societa',
#        'Cloud Imperium Games Corporation', 'Interchannel', 'Flight-Plan',
#        'Funsta', 'Reef Entertainment', 'Experience Inc.', 'Sonnet',
#        'Rage Software', 'Virtual Play Games', 'Tru Blu Entertainment',
#        'Zenrin', 'Dusenberry Martin Racing', 'Cave', 'Games Workshop',
#        'Playlogic Game Factory', 'Global A Entertainment',
#        'Kalypso Media', 'Office Create', 'Maximum Family Games', 'Sting',
#        'Fields', 'Princess Soft', 'Extreme Entertainment Group',
#        'Big Fish Games', 'Berkeley', 'Fuji', 'FuRyu Corporation',
#        'Her Interactive', 'imageepoch Inc.', 'Kamui', 'ASK', 'Cygames',
#        'HMH Interactive', '49Games', 'KSS', 'dramatic create', 'TGL',
#        'KID', 'Paradox Interactive', 'Quinrose', 'Encore', 'G.Rev',
#        'Sweets', 'Kokopeli Digital Studios', 'Nexon', '10TACLE Studios',
#        'BushiRoad', 'Wargaming.net', 'Screenlife', 'Tryfirst',
#        'GN Software', 'System 3', "Yuke's", 'Alternative Software',
#        'Russel', 'Groove Games', 'Paon Corporation', 'Kids Station',
#        'Licensed 4U', 'Edia', '7G//AMES', 'King Records',
#        'Minato Station', 'Easy Interactive', 'Gaga',
#        'Yamasa Entertainment', 'Plenty', 'Devolver Digital', 'Daedalic',
#        'Views', 'Blue Byte', 'fonfun', 'NetRevo', 'Epic Games', 'Quintet',
#        'Focus Multimedia', 'Marvelous Games', 'Dorart', 'Athena',
#        'Aerosoft', 'Imageworks', 'Karin Entertainment',
#        'Technos Japan Corporation', 'Masque Publishing', 'Gakken',
#        'New World Computing', 'Sunrise Interactive', 'Mirai Shounen',
#        'Wanadoo', 'Datam Polystar', 'HuneX', 'Saurus',
#        'Revolution (Japan)', 'Giza10', 'NovaLogic', 'Alvion', 'Giga',
#        'Mycom', 'Warashi', 'System Soft', 'RED Entertainment',
#        'Michaelsoft', 'Media Entertainment', 'Genterprise',
#        'Interworks Unlimited, Inc.', 'Ascaron Entertainment GmbH',
#        'Inti Creates', 'Boost On', 'Microids', 'Moss',
#        'EON Digital Entertainment', 'Nitroplus', 'Naxat Soft', 'Piacci',
#        'Liquid Games', 'Otomate', 'Ascaron Entertainment',
#        'Milestone S.r.l', 'Ongakukan', 'Commseed', 'UIG Entertainment',
#        'Takuyo', 'Interchannel-Holon', 'Red Flagship',
#        'Excalibur publishing', 'Trion Worlds', 'Telstar',
#        'DreamWorks Interactive', 'DHM Interactive', 'FunSoft', 'SPS',
#        'T&E Soft', 'Hearty Robin', 'Nippon Amuse', 'Origin Systems',
#        'bitComposer Games', 'Seventh Chord', 'Abylight', 'Mitsui',
#        'Agatsuma Entertainment', 'Glams', 'Locus', 'Warp', 'Elite',
#        'Evolution Games', 'Aria', 'Altron', 'Fortyfive', 'Imax',
#        'Crimson Cow', 'iWin', 'Sony Online Entertainment',
#        'Vatical Entertainment', 'Ecole', 'Xseed Games', 'Yumedia'],
#       dtype=object)

# %%
data[data.Name.isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %%
l = dict(data.Name[data.Publisher.isnull()])

# %%
l
# Out:
# {475: 'wwe Smackdown vs. Raw 2006',
#  1301: 'Triple Play 99',
#  1667: 'Shrek / Shrek 2 2-in-1 Gameboy Advance Video',
#  2212: "Bentley's Hackpack",
#  3148: 'Nicktoons Collection: Game Boy Advance Video Volume 1',
#  3159: 'SpongeBob SquarePants: Game Boy Advance Video Volume 1',
#  3755: 'SpongeBob SquarePants: Game Boy Advance Video Volume 2',
#  4127: 'Sonic the Hedgehog',
#  4508: 'The Fairly Odd Parents: Game Boy Advance Video Volume 1',
#  4615: 'The Fairly Odd Parents: Game Boy Advance Video Volume 2',
#  5294: 'Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)',
#  5633: 'Cartoon Network Collection: Game Boy Advance Video Platinum Edition',
#  6256: 'The Legend of Zelda: The Minish Cap(weekly JP sales)',
#  6415: 'Sonic X: Game Boy Advance Video Volume 1',
#  6532: 'Dora the Explorer: Game Boy Advance Video Volume 1',
#  6626: 'Cartoon Network Collection: Game Boy Advance Video Volume 1',
#  6831: 'All Grown Up!: Game Boy Advance Video Volume 1',
#  7189: 'Nicktoons Collection: Game Boy Advance Video Volume 2',
#  7333: 'Yu Yu Hakusho: Dark Tournament',
#  7477: 'SpongeBob SquarePants: Game Boy Advance Video Volume 3',
#  7930: 'Thomas the Tank Engine & Friends',
#  8317: 'Dragon Ball GT: Game Boy Advance Video Volume 1',
#  8328: 'Codename: Kids Next Door: Game Boy Advance Video Volume 1',
#  8358: 'Teenage Mutant Ninja Turtles: Game Boy Advance Video Volume 1',
#  8494: 'Stronghold 3',
#  8754: 'Cartoon Network Collection: Game Boy Advance Video Special Edition',
#  8837: 'Pokémon: Johto Photo Finish: Game Boy Advance Video',
#  8883: 'Strawberry Shortcake: Game Boy Advance Video Volume 1',
#  9703: 'Disney Channel Collection Vol. 1',
#  9812: 'Atsumare! Power Pro Kun no DS Koushien',
#  10418: 'Action Man-Operation Extreme',
#  11175: 'Monster Hunter Frontier Online',
#  11569: 'B.L.U.E.: Legend of Water',
#  11985: 'Housekeeping',
#  12209: 'Bikkuriman Daijiten',
#  12544: 'World of Tanks',
#  12629: 'UK Truck Simulator',
#  12881: 'Umineko no Naku Koro ni San: Shinjitsu to Gensou no Yasoukyoku',
#  13197: 'Mario Tennis',
#  13274: 'Nicktoons Collection: Game Boy Advance Video Volume 3',
#  13299: 'Demolition Company: Gold Edition',
#  13537: 'Moshi, Kono Sekai ni Kami-sama ga Iru to suru Naraba.',
#  13876: 'Dream Dancer',
#  14137: 'Homeworld Remastered Collection',
#  14153: 'AKB1/48: Idol to Guam de Koishitara...',
#  14163: 'Super Robot Monkey Team: Game Boy Advance Video Volume 1',
#  14189: 'Brothers in Arms: Furious 4',
#  14196: 'Dance with Devils',
#  14519: 'Driving Simulator 2011',
#  14747: 'Farming Simulator 2011',
#  14975: 'Super Robot Wars OG Saga: Masou Kishin II - Revelation of Evil God',
#  15621: 'Cartoon Network Collection: Game Boy Advance Video Volume 2',
#  16600: 'Chou Soujuu Mecha MG',
#  16644: 'Prinny: Can I Really Be The Hero? (US sales)'}

# %%
data.Publisher[data.Name==l[475]] = "THQ"
data.Publisher[data.Name==l[1301]] = "Electronic Arts"
data.Publisher[data.Name==l[1667]] ="Take-Two Interactive"
data.Publisher[data.Name==l[2212]] ="Sony Computer Entertainment"
data.Publisher[data.Name==l[3148]] ="Majesco Entertainment"
data.Publisher[data.Name==l[3159]] ="Majesco Entertainment"
data.Publisher[data.Name==l[3755]] ="Majesco Entertainment"
data.Publisher[data.Name==l[4127]] ="Sega"
data.Publisher[data.Name==l[4508]] ="THQ"
data.Publisher[data.Name==l[4615]] ="THQ"
data.Publisher[data.Name==l[5294]] ="Nintendo"
data.Publisher[data.Name==l[5633]] ="Majesco Entertainment"
data.Publisher[data.Name==l[6256]] ="Nintendo"
data.Publisher[data.Name==l[6415]] ="Majesco Entertainment"
data.Publisher[data.Name==l[6532]] ="Gotham Games"
data.Publisher[data.Name==l[6626]] ="Nintendo"
data.Publisher[data.Name==l[6831]] ="THQ"
data.Publisher[data.Name==l[7189]] ="Nintendo"
data.Publisher[data.Name==l[7333]] ="Atari"
data.Publisher[data.Name==l[7477]] ="Nintendo"
data.Publisher[data.Name==l[7930]] ="THQ"
data.Publisher[data.Name==l[8317]]="Nintendo"
data.Publisher[data.Name==l[8328]]="Global Star"
data.Publisher[data.Name==l[8358]]="Konami Digital Entertainment"
data.Publisher[data.Name==l[8494]]="Unknown"
data.Publisher[data.Name==l[8754]]="Majesco Entertainment"
data.Publisher[data.Name==l[8837]]="Nintendo"
data.Publisher[data.Name==l[8883]]="Nintendo"
data.Publisher[data.Name==l[9703]]="Majesco Entertainment"
data.Publisher[data.Name==l[9812]]="Konami Digital Entertainment"
data.Publisher[data.Name==l[10418]]="Habro Interactive"
data.Publisher[data.Name==l[11175]]="Microsoft Game Studios"
data.Publisher[data.Name==l[11569]]="Hudson soft"
data.Publisher[data.Name==l[11985]]="Unknown"
data.Publisher[data.Name==l[12209]]="Nintendo"
data.Publisher[data.Name==l[12544]]="Wargaming.net"
data.Publisher[data.Name==l[12629]]="Nintendo"
data.Publisher[data.Name==l[12881]]="Sony Computer Entertainment"
data.Publisher[data.Name==l[13197]] = "Nintendo"
data.Publisher[data.Name==l[13274]] = "Nintendo"
data.Publisher[data.Name==l[13299]] = "Nintendo"
data.Publisher[data.Name==l[13537]] = "Unknown"
data.Publisher[data.Name==l[13876]] = "Zoo Games"
data.Publisher[data.Name==l[14137]] = "Gearbox Software"
data.Publisher[data.Name==l[14153]] = "Unknown"
data.Publisher[data.Name==l[14163]] = "Majesco Entertainment"
data.Publisher[data.Name==l[14189]] = "Ubisoft"
data.Publisher[data.Name==l[14196]] = "Unknown"
data.Publisher[data.Name==l[14519]] = "Excalibur publishing"
data.Publisher[data.Name==l[14747]] = "Unknown"
data.Publisher[data.Name==l[14975]] = "Unknown"
data.Publisher[data.Name==l[15621]] = "Majesco Entertainment"
data.Publisher[data.Name==l[16600]] = "Nintendo"
data.Publisher[data.Name==l[16644]] = "Nintendo"
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[475]] = "THQ"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[1301]] = "Electronic Arts"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[1667]] ="Take-Two Interactive"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[2212]] ="Sony Computer Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[3148]] ="Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[3159]] ="Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[3755]] ="Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[4127]] ="Sega"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[4508]] ="THQ"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[4615]] ="THQ"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[5294]] ="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[5633]] ="Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[6256]] ="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[6415]] ="Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[6532]] ="Gotham Games"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[6626]] ="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[6831]] ="THQ"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[7189]] ="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[7333]] ="Atari"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[7477]] ="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[7930]] ="THQ"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[8317]]="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[8328]]="Global Star"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[8358]]="Konami Digital Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[8494]]="Unknown"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[8754]]="Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[8837]]="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[8883]]="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[9703]]="Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[9812]]="Konami Digital Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[10418]]="Habro Interactive"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[11175]]="Microsoft Game Studios"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[11569]]="Hudson soft"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[11985]]="Unknown"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[12209]]="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[12544]]="Wargaming.net"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[12629]]="Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[12881]]="Sony Computer Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[13197]] = "Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[13274]] = "Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[13299]] = "Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[13537]] = "Unknown"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[13876]] = "Zoo Games"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14137]] = "Gearbox Software"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14153]] = "Unknown"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14163]] = "Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14189]] = "Ubisoft"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14196]] = "Unknown"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14519]] = "Excalibur publishing"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14747]] = "Unknown"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[14975]] = "Unknown"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[15621]] = "Majesco Entertainment"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[16600]] = "Nintendo"
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/894142974.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Publisher[data.Name==l[16644]] = "Nintendo"

# %%
data.Year_of_Release.fillna("Unknown year",inplace =True)

# %%
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/3974168093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Critic_Score[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])]=data.Critic_Score[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])].fillna(csma)
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/3974168093.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Critic_Count[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])]=data.Critic_Count[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])].fillna(ccma)
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/3974168093.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.User_Score[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])]=data.User_Score[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])].fillna(usma)
# C:\Users\HP\AppData\Local\Temp/ipykernel_6016/3974168093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.User_Count[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])]=data.User_Count[(data.Genre ==Genl[i]) & (data.Publisher==Publ[j])].fillna(ucma)

# %%
Genl = list(data.Genre[data.Critic_Count.isnull()].unique())
Publ = list(data.Publisher[data.Critic_Count.isnull()].unique())

# %%
Genl
# Out:
# ['Platform',
#  'Role-Playing',
#  'Puzzle',
#  'Shooter',
#  'Simulation',
#  'Action',
#  'Adventure',
#  'Racing',
#  'Misc',
#  'Sports',
#  'Fighting',
#  'Strategy']

# %%
data[(data.Genre ==Genl[0]) & (data.Publisher==Publ[0])]
# Out:
#                                                   Name Platform  \
# 1                                    Super Mario Bros.      NES
# 6                                New Super Mario Bros.       DS
# 8                            New Super Mario Bros. Wii      Wii
# 18                                   Super Mario World     SNES
# 21                                    Super Mario Land       GB
# ...                                                ...      ...
# 8396                               Densetsu no Stafi 4       DS
# 10074                              Famicom Mini: Mappy      GBA
# 13945                          Donkey Kong Jungle Beat      Wii
# 15380                        Famicom Mini: Mario Bros.      GBA
# 15868  Famicom Mini: Hikari Shinwa: Palutena no Kagami      GBA
#
#       Year_of_Release     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1              1985.0  Platform  Nintendo     29.08      3.58      6.81
# 6              2006.0  Platform  Nintendo     11.28      9.14      6.50
# 8              2009.0  Platform  Nintendo     14.44      6.94      4.70
# 18             1990.0  Platform  Nintendo     12.78      3.75      3.54
# 21             1989.0  Platform  Nintendo     10.83      2.71      4.18
# ...               ...       ...       ...       ...       ...       ...
# 8396           2006.0  Platform  Nintendo      0.00      0.00      0.17
# 10074          2004.0  Platform  Nintendo      0.00      0.00      0.09
# 13945          2008.0  Platform  Nintendo      0.00      0.01      0.00
# 15380          2004.0  Platform  Nintendo      0.00      0.00      0.08
# 15868          2004.0  Platform  Nintendo      0.00      0.00      0.07
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 1              80.0          83.0        8.9        44.0       NaN    NaN
# 6              89.0          65.0        8.5       431.0  Nintendo      E
# 8              87.0          80.0        8.4       594.0  Nintendo      E
# 18             80.0          83.0        8.9        44.0       NaN    NaN
# 21             80.0          83.0        8.9        44.0       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 8396           80.0          83.0        8.9        44.0       NaN    NaN
# 10074          80.0          83.0        8.9        44.0       NaN    NaN
# 13945          80.0          83.0        8.9        44.0       NaN    NaN
# 15380          80.0          83.0        8.9        44.0       NaN    NaN
# 15868          80.0          83.0        8.9        44.0       NaN    NaN
#
# [112 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Critic_Score          0
# Critic_Count          0
# User_Score            0
# User_Count            0
# Developer          6621
# Rating             6767
# dtype: int64

# %%
data.Critic_Score.fillna(data.Critic_Score.mode().max(),inplace = True)
data.Critic_Count.fillna(data.Critic_Count.mode().max(),inplace = True)
data.User_Score.fillna(data.User_Score.mode().max(),inplace =True)
data.User_Count.fillna(data.User_Count.mode().max(),inplace =True)
